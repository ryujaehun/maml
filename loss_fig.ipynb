# %%
import pandas as pd
import glob
import os

# %%
paths=glob.glob('*csv')

# %%
for path in paths:
    name=path[:path.rfind('_')]
    kind=path[path.rfind('_')+1:path.rfind('.')]
    df=pd.read_csv(path,index_col=0)
    title=f'{name}_{kind}_loss'
    fig=df[:3].T.plot.bar(figsize=(12,12),grid=True,rot=45,title=title)
    fig.get_figure().savefig(f'{title}.png')
    fig.clear()
    
    title=f'{name}_{kind}_svcca_baseline_no-adapt'
    fig=df[3:7].T.plot.bar(figsize=(12,12),grid=True,rot=45,title=title)
    fig.get_figure().savefig(f'{title}.png')
    fig.clear()
    
    title=f'{name}_{kind}_svcca_baseline_adapt'
    fig=df[7:11].T.plot.bar(figsize=(12,12),grid=True,rot=45,title=title)
    fig.get_figure().savefig(f'{title}.png')
    fig.clear()
    
    title=f'{name}_{kind}_svcca_no-adapt_adapt'
    fig=df[11:15].T.plot.bar(figsize=(12,12),grid=True,rot=45,title=title)
    fig.get_figure().savefig(f'{title}.png')
    fig.clear()
